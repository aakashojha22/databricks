# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/MicrosoftLearning/mslearn-databricks/main/data/products.csv")

# %%
df

# %%
dbutils.fs.mount(source='wasbs://databrickstarget@intellipaatteststorageac.blob.core.windows.net', mount_point='/mnt/databrickstarget',extra_configs={'fs.azure.sas.databrickstarget.intellipaatteststorageac.blob.core.windows.net':'sp=racwdlmeop&st=2025-01-08T17:05:31Z&se=2025-01-09T01:05:31Z&spr=https&sv=2022-11-02&sr=c&sig=qCY8rPs3z4%2Bzhxj1knBN9Qj12PfW%2BNEOvg%2FG5%2FO0NHA%3D'})

# %%
dbutils.fs.ls('/mnt/databrickstarget')

# %%
df.to_csv('/dbfs/mnt/databrickstarget/product.csv')

# %%
df.to_parquet('/dbfs/mnt/databrickstarget/product.parquet')
